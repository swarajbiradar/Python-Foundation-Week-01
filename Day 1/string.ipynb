# %%
name = "Alice"
course = "Python Programming"
city = "Bangalore"

print("Name:", name)
print("Course:", course)
print("City:", city)
# Out:
# Name: Alice
# Course: Python Programming
# City: Bangalore
