# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact = fact * i
    return fact

print("Factorial of 5:", factorial(5))
print("Factorial of 6:", factorial(6))
# Out:
# Factorial of 5: 120
# Factorial of 6: 720
